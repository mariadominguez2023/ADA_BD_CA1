# %% [markdown]
# ## Credit Card Fraud Detection Dataset
#
# The approach proposed by this study is to use deep learning applying Artificial Neural Network to identify fraud credit card transactions. Neural Networks have been proved to performed better on big data rather than conventional machine learning models as they require more training data.
#
# The Credit Card Fraud Detection from Kaggle has been used in order to apply the theory of Deep learning using Big Data.
#
# Data set is 309 MB which is considered to be Big Data.
#
# An ANN and Random Forest models are going to be prepared to check their performance when usisng big data.

# %%
#pip install tensorflow

# %%
#pip install keras

# %%
#Import the libraries
import matplotlib
matplotlib.use("TkAgg")
import pandas as pd
import seaborn as sns
import numpy as np
from keras.datasets import reuters
from keras.preprocessing.text import Tokenizer
from keras import models
from keras import layers
from matplotlib import pyplot as plt 
# %matplotlib inLine
sns.set(color_codes=True) 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## EDA Analysis

# %% [markdown]
# **Data Cleaning**

# %%
#load the dataset
Credit = pd.read_csv('Creditcard_2023.csv')

# %%
#Checking the first 5 rows
Credit.head()
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0 -0.130006  0.727159  ... -0.110552  0.217606 -0.134794  0.165959  0.126280
# 1 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469 -0.577395  0.190090
# 2 -0.095576 -0.261297  ... -0.005020  0.702906  0.945045 -1.154666 -0.605564
# 3 -0.065130 -0.205698  ... -0.146927 -0.038212 -0.214048 -1.893131  1.003963
# 4 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666  0.312561 -0.414116
#
#         V26       V27       V28    Amount  Class
# 0 -0.434824 -0.081230 -0.151045  17982.10      0
# 1  0.296503 -0.248052 -0.064512   6531.37      0
# 2 -0.312895 -0.300258 -0.244718   2513.54      0
# 3 -0.515950 -0.165316  0.048424   5384.44      0
# 4  1.071126  0.023712  0.419117  14278.97      0
#
# [5 rows x 31 columns]

# %%
#Check the shape of the  data
Credit.shape
# Out:
# (568630, 31)

# %%
#Checking the types of variables
Credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
#  20  V20     568630 non-null  float64
#  21  V21     568630 non-null  float64
#  22  V22     568630 non-null  float64
#  23  V23     568630 non-null  float64
#  24  V24     568630 non-null  float64
#  25  V25     568630 non-null  float64
#  26  V26     568630 non-null  float64
#  27  V27     568630 non-null  float64
#  28  V28     568630 non-null  float64
#  29  Amount  568630 non-null  float64
#  30  Class   568630 non-null  int64
# dtypes: float64(29), int64(2)
# memory usage: 134.5 MB

# %%
#checking categorical values on that dataset
#Credit.describe(include=object)

# %%
#checking the null values.
Credit.isnull().sum()
# Out:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#Credit.isnull().values.any()

# %%
#Credit.isnull().sum()

# %%
#checking for unique values in dataset
Credit.nunique()
# Out:
# id        568630
# V1        552035
# V2        552035
# V3        552035
# V4        552035
# V5        552035
# V6        552035
# V7        552035
# V8        552035
# V9        552035
# V10       552035
# V11       552035
# V12       552035
# V13       552035
# V14       552035
# V15       552035
# V16       552035
# V17       552035
# V18       552035
# V19       552035
# V20       552035
# V21       552035
# V22       552035
# V23       552035
# V24       552035
# V25       552035
# V26       552035
# V27       552035
# V28       552035
# Amount    506485
# Class          2
# dtype: int64

# %%
#Columns "ID" will be dropped as it will not produce any valuable information.

#Dropping feature.
Credit = Credit.drop(['id'], axis=1)

# %%
#Checking credit dataset head after dropping columns
Credit.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0 -0.130006  0.727159  0.637735  ... -0.110552  0.217606 -0.134794  0.165959
# 1 -0.133118  0.347452  0.529808  ... -0.194936 -0.605761  0.079469 -0.577395
# 2 -0.095576 -0.261297  0.690708  ... -0.005020  0.702906  0.945045 -1.154666
# 3 -0.065130 -0.205698  0.575231  ... -0.146927 -0.038212 -0.214048 -1.893131
# 4 -0.212660  1.049921  0.968046  ... -0.106984  0.729727 -0.161666  0.312561
#
#         V25       V26       V27       V28    Amount  Class
# 0  0.126280 -0.434824 -0.081230 -0.151045  17982.10      0
# 1  0.190090  0.296503 -0.248052 -0.064512   6531.37      0
# 2 -0.605564 -0.312895 -0.300258 -0.244718   2513.54      0
# 3  1.003963 -0.515950 -0.165316  0.048424   5384.44      0
# 4 -0.414116  1.071126  0.023712  0.419117  14278.97      0
#
# [5 rows x 30 columns]

# %%
#checking the duplicates in the dataset
duplicate_rows=Credit[Credit.duplicated()] 
print('number of duplicate rows: ', duplicate_rows.shape)
# Out:
# number of duplicate rows:  (1, 30)

# %%
# Used to count the number of rows before removing the data 
Credit.count()
# Out:
# V1        568630
# V2        568630
# V3        568630
# V4        568630
# V5        568630
# V6        568630
# V7        568630
# V8        568630
# V9        568630
# V10       568630
# V11       568630
# V12       568630
# V13       568630
# V14       568630
# V15       568630
# V16       568630
# V17       568630
# V18       568630
# V19       568630
# V20       568630
# V21       568630
# V22       568630
# V23       568630
# V24       568630
# V25       568630
# V26       568630
# V27       568630
# V28       568630
# Amount    568630
# Class     568630
# dtype: int64

# %%
# Dropping the duplicates 
Credit = Credit.drop_duplicates() 
Credit.head(5)
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0 -0.130006  0.727159  0.637735  ... -0.110552  0.217606 -0.134794  0.165959
# 1 -0.133118  0.347452  0.529808  ... -0.194936 -0.605761  0.079469 -0.577395
# 2 -0.095576 -0.261297  0.690708  ... -0.005020  0.702906  0.945045 -1.154666
# 3 -0.065130 -0.205698  0.575231  ... -0.146927 -0.038212 -0.214048 -1.893131
# 4 -0.212660  1.049921  0.968046  ... -0.106984  0.729727 -0.161666  0.312561
#
#         V25       V26       V27       V28    Amount  Class
# 0  0.126280 -0.434824 -0.081230 -0.151045  17982.10      0
# 1  0.190090  0.296503 -0.248052 -0.064512   6531.37      0
# 2 -0.605564 -0.312895 -0.300258 -0.244718   2513.54      0
# 3  1.003963 -0.515950 -0.165316  0.048424   5384.44      0
# 4 -0.414116  1.071126  0.023712  0.419117  14278.97      0
#
# [5 rows x 30 columns]

# %%
#checking shape of data after removing duplicated rows
Credit.shape
# Out:
# (568629, 30)

# %%
# Visualizing the results of the test through a Boxplot:
#sns.set(rc={"figure.figsize":(4, 6)})
#sns.boxplot(data=Credit, x="Class", y="Amount")
#plt.title('Box plot of Target by Income',
          #fontsize=13)

# %%
# Number of transaction, Where "0" is legitimate transactions and "1" is fraud transactions
Credit["Class"].value_counts()
# Out:
# 0    284315
# 1    284314
# Name: Class, dtype: int64

# %%
# Bar chart where it can be shown fraud and no fraud transaction. It is balanced amount of transactions.
sns.set(rc={"figure.figsize":(5, 3)})
sns.catplot(x="Class", data=Credit, kind="count", hue='Class'); 
plt.title("Distribution Class variable")
plt.legend(["No Fraud", "Fraud"])
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1));

# %%
#Checking summary statistics on dataset
#When checking summary statisticis it is shown that there are outliers in the dataset.
Credit.describe()
# Out:
#                   V1             V2             V3            V4  \
# count  568629.000000  568629.000000  568629.000000  5.686290e+05
# mean        0.000003      -0.000005       0.000002 -8.855104e-07
# std         0.999999       0.999996       1.000000  1.000002e+00
# min        -3.495584     -49.966572      -3.183760 -4.951222e+00
# 25%        -0.565285      -0.486680      -0.649298 -6.560208e-01
# 50%        -0.093636      -0.135894       0.000354 -7.376398e-02
# 75%         0.832658       0.343553       0.628539  7.070060e-01
# max         2.229046       4.361865      14.125834  3.201536e+00
#
#                   V5             V6             V7             V8  \
# count  568629.000000  568629.000000  568629.000000  568629.000000
# mean        0.000002      -0.000006       0.000004       0.000011
# std         1.000001       0.999993       0.999997       0.999970
# min        -9.952786     -21.111108      -4.351839     -10.756342
# 25%        -0.293495      -0.445872      -0.283533      -0.192257
# 50%         0.081089       0.078716       0.233367      -0.114523
# 75%         0.439738       0.497788       0.525955       0.047299
# max        42.716891      26.168402     217.873038       5.958040
#
#                  V9            V10  ...            V21            V22  \
# count  5.686290e+05  568629.000000  ...  568629.000000  568629.000000
# mean  -4.807863e-07       0.000001  ...      -0.000014       0.000011
# std    1.000002e+00       1.000001  ...       0.999944       0.999965
# min   -3.751919e+00      -3.163276  ...     -19.382523      -7.734798
# 25%   -5.687501e-01      -0.590101  ...      -0.166441      -0.490486
# 50%    9.252585e-02       0.262617  ...      -0.037431      -0.027327
# 75%    5.592661e-01       0.592462  ...       0.147976       0.463887
# max    2.027006e+01      31.722709  ...       8.087080      12.632511
#
#                  V23            V24           V25           V26  \
# count  568629.000000  568629.000000  5.686290e+05  5.686290e+05
# mean       -0.000011       0.000002 -6.153061e-07  4.225269e-07
# std         0.999966       1.000001  1.000002e+00  1.000002e+00
# min       -30.295450      -4.067968 -1.361263e+01 -8.226969e+00
# 25%        -0.237629      -0.651580 -5.541491e-01 -6.318949e-01
# 50%        -0.059689       0.015903 -8.193948e-03 -1.189070e-02
# 75%         0.155715       0.700740  5.500149e-01  6.728885e-01
# max        31.707627      12.965639  1.462151e+01  5.623285e+00
#
#                  V27            V28         Amount          Class
# count  568629.000000  568629.000000  568629.000000  568629.000000
# V6     -0.005231 -0.195344 -0.067605 -0.260795 -0.065655  0.000725 -0.435098
# V7     -0.004156  0.000804 -0.006489 -0.036551  0.040741  0.001332 -0.491233
# V8      0.083263  0.322654  0.040447  0.298425  0.046042 -0.000192  0.144309
# V9      0.044007 -0.034885 -0.131000 -0.111843  0.069958 -0.001589 -0.585523
# V10     0.045934 -0.014045 -0.053684 -0.134905  0.035649 -0.001258 -0.673665
# V11    -0.104338  0.051535  0.133635  0.290910  0.059729  0.000289  0.724278
# V12     0.080406 -0.010350 -0.114273 -0.216562 -0.053133 -0.001243 -0.768579
# V13     0.060093  0.003581  0.043750  0.058489 -0.101481 -0.002713 -0.071102
# V14     0.138716 -0.087040 -0.142472 -0.299948 -0.127965 -0.001360 -0.805669
# V15     0.023002 -0.027579  0.047833  0.116107  0.100294  0.001191 -0.037948
# V16    -0.023513  0.062485 -0.056185 -0.191739 -0.022323 -0.000476 -0.573510
# V17    -0.072199  0.075610 -0.045189 -0.184548  0.019572 -0.000356 -0.476376
# V18    -0.099747  0.070468 -0.021039 -0.141787  0.052551 -0.001514 -0.410090
# V19     0.110751 -0.174328  0.041420  0.123267 -0.024368 -0.000400  0.244082
# V20    -0.020324  0.030481  0.007675 -0.055172 -0.035712 -0.001394  0.179861
# V21    -0.059178  0.146167  0.070057  0.373257  0.326666  0.001007  0.109632
# V22     0.079781 -0.258962 -0.015130 -0.340635 -0.282880 -0.000925  0.014110
# V23    -0.051170 -0.040887  0.001059 -0.151720  0.028036 -0.001998  0.010244
# V24     1.000000 -0.079603 -0.113363 -0.194897 -0.045185 -0.000843 -0.130105
# V25    -0.079603  1.000000  0.057547  0.215652  0.176057 -0.000721  0.061846
# V26    -0.113363  0.057547  1.000000  0.193978  0.036831 -0.000120  0.071052
# V27    -0.194897  0.215652  0.193978  1.000000  0.183229  0.001231  0.214000
# V28    -0.045185  0.176057  0.036831  0.183229  1.000000 -0.001509  0.102020
# Amount -0.000843 -0.000721 -0.000120  0.001231 -0.001509  1.000000  0.002258
# Class  -0.130105  0.061846  0.071052  0.214000  0.102020  0.002258  1.000000
#
# [30 rows x 30 columns]

# %%
# Finding the relations between the variables through a heat map
plt.figure(figsize=(35,25)) 
c= Credit.corr() 
sns.heatmap(c,cmap="BrBG",annot=True) 
plt.title("Correlation between variables for Credit");
# There is a moderate correlation between V2 an Class variables. As well as that, there is a strong correlation of 0.71 between V12 and V3. 
# There is a strong correlation of 0.78 between V12 and V14. A moderate correlation between V1 and V14.

# %%
#Ploting a scatter plot to stablish if there is any correlation between two variables

fig, ax = plt.subplots(figsize=(8,4)) 
#sns.set_style('whitegrid')
sns.set_palette('rainbow')#
sns.scatterplot(data=Credit, x='V10', y='V9', alpha=0.7)
plt.title("Correlation between variables V9 and V10");
plt.show()

# %%
# Visualizing the Income variable
# It can be seen that data is positive skewed in this feature.
sns.set(rc={"figure.figsize":(3, 1)})
sns.displot(data=Credit, x="V16", kde=True);
plt.title("V16 variable data shape");

# %%
# Visualizing the Age variable
# It can be seen that data follow a normal distribution.
sns.set(rc={"figure.figsize":(4, 1)})
sns.displot(data=Credit, x="V4", kde=True);
plt.title("V4 feature data shape");

# %% [markdown]
# ## Outliers detection

# %%
# Detecting Outliers
# As it can be seen below, there are ouliers in three of the numeric variables of my dataset.
sns.set(rc={"figure.figsize":(4, 3)})
sns.boxplot(x=Credit['V11']); 
plt.title("V11 variable outliers");

# %%
#Checking outliers in others variables
col_dict = {'V1':1 , 'V2':2 ,
        'V5':3 , 'V6': 4, 'V7':5, 'V8':6, 'V9':7, 'V10':8}

# %%
#Checking 8 variables to detect outliers in dataset
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt 
plt.figure(figsize=(20,30))

for variable,i in col_dict.items():
                     plt.subplot(5,4,i)
                     plt.boxplot(Credit[variable],whis=1.5)
                     plt.title(variable)

plt.show()

# %% [markdown]
# ## Machine Learning section
#
# Deep learning models have been used since there are able to read complex patherns in the data and therefore make more accurate predictions that standard machine learning models. Thus, a ANN model will be performed on this dataset.

# %% [markdown]
# ## **Data Preparation**

# %%
#Credit.info()

# %% [markdown]
# **Select X and y**
# First time this model was tested, all variable were used, but it resulted in an overfitting model. That was the reason
# that variables were reduced as shown in next step

# %%
# Select X and y 
#X = Credit.loc[:, Credit.columns != 'Class']
#y = Credit.loc[:, 'Class']

# %%
# Select X and y 
X = Credit.loc[:, [ 'V6', 'V7', 'V8', 'V9','V10', 'V11', 'V12','V13', 'V14', 'V15','V16', 'V17', 'V18', 'V19', 'V20','V21','V22']] # independent variables

y = Credit['Class']# dependent variable
# Out:
#               V6        V7        V8        V9       V10       V11       V12  \
# 0       0.732898  0.519014 -0.130006  0.727159  0.637735 -0.987020  0.293438
# 1       0.428605  0.406466 -0.133118  0.347452  0.529808  0.140107  1.564246
# 2       1.419481  0.743511 -0.095576 -0.261297  0.690708 -0.272985  0.659201
# 3       1.143312  0.518269 -0.065130 -0.205698  0.575231 -0.752581  0.737483
# 4       0.530549  0.658849 -0.212660  1.049921  0.968046 -1.203171  1.029577
# ...          ...       ...       ...       ...       ...       ...       ...
# 568625  0.481454 -0.370393  0.189694 -0.938153 -1.161847  1.430971 -1.330500
# 568626  0.237148 -0.016935 -0.147733  0.483894 -0.210817  0.173590 -0.539948
# 568627  0.121098 -0.070958 -0.019997 -0.122048 -0.144495  0.477582 -0.461849
# 568628 -0.294148  0.580568 -0.207723  0.893527 -0.080078 -0.324934  0.335215
# 568629 -0.603493 -0.347613 -0.340814  0.253971 -0.513556  0.892136 -1.153011
#
#              V13       V14       V15       V16       V17       V18       V19  \
# 0      -0.941386  0.549020  1.804879  0.215598  0.512307  0.333644  0.124270
# 1       0.574074  0.627719  0.706121  0.789188  0.403810  0.201799 -0.340687
# 2       0.805173  0.616874  3.069025 -0.577514  0.886526  0.239442 -2.366079
# 3       0.592994  0.559535 -0.697664 -0.030669  0.242629  2.178616 -1.345060
# 4       1.439310  0.241454  0.153008  0.224538  0.366466  0.291782  0.445317
# ...          ...       ...       ...       ...       ...       ...       ...
# 568625 -1.580730 -1.363454  0.287766 -1.480796 -1.520928 -1.376970  1.789103
# 568626  0.738315 -0.812043  0.870447 -0.545184 -0.575991 -0.664313  0.101604
# 568627 -0.606100 -0.395126 -0.040673 -0.370201 -0.729002 -0.251679 -0.343196
# 568628  0.464177 -0.390369  0.893881  0.477402  0.848443  0.930280 -0.481058
# 568629  0.489197 -1.062488  0.207773 -0.917240 -0.936114 -0.823688 -0.330408
#
#              V20       V21       V22
# 0       0.091202 -0.110552  0.217606
# 1      -0.233984 -0.194936 -0.605761
# 2       0.361652 -0.005020  0.702906
# 3      -0.378223 -0.146927 -0.038212
# 4       0.247237 -0.106984  0.729727
# ...          ...       ...       ...
# 568625 -0.751011  0.167503  0.419731
# 568626 -0.550260  0.031874  0.388161
# 568627 -0.076417  0.140788  0.536523
# 568628  0.288186 -0.060381 -0.195609
# 568629 -0.621378  0.534853 -0.291514
#
# [568629 rows x 17 columns]

# %%
#X

# %%
#y

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 1, stratify=y) #58 #test_size = 0.25, random_state = 0

# %%
## performing preprocessing part
from sklearn.preprocessing import StandardScaler

# Create and initialise an object (sc) by calling a method named as StandardScaler()
sc = StandardScaler()

# Train the model by calling a method fit_transform()
X_train = sc.fit_transform(X_train)

# Transform the data into standised form
X_test = sc.transform(X_test)

# %%
#y

# %% [markdown]
# ## Builiding an Artificial Neural Network model (ANN)

# %%
from keras.layers import Dense
from keras.models import Sequential

# Build neural network in Keras
model = Sequential()

# Add fully connected layer with a ReLU activation function
model.add(Dense(10, input_dim=17, activation='relu', )) # 10

# Add fully connected layer with a ReLU activation function
model.add(Dense(2, activation='relu')) #3

# Add fully connected layer with a sigmoid activation function - Output layer
model.add(Dense(1, activation='sigmoid')) # output layer

# %%
#Checking summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                180
#
#  dense_1 (Dense)             (None, 2)                 22
#
#  dense_2 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 205 (820.00 Byte)
# Trainable params: 205 (820.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile neural network
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])  
model.fit(X_train, y_train, epochs=25, batch_size=100)#, verbose=False)  99.22..last loss 0.0276   acc 0.9908
# Out:
# Epoch 1/25
# 4550/4550 [==============================] - 10s 2ms/step - loss: 0.1986 - accuracy: 0.9465
# Epoch 2/25
# 4550/4550 [==============================] - 9s 2ms/step - loss: 0.1224 - accuracy: 0.9575
# Epoch 3/25
# 4550/4550 [==============================] - 8s 2ms/step - loss: 0.1164 - accuracy: 0.9590
# Epoch 4/25
# 4550/4550 [==============================] - 10s 2ms/step - loss: 0.1121 - accuracy: 0.9601
# Epoch 5/25
# 4550/4550 [==============================] - 9s 2ms/step - loss: 0.1082 - accuracy: 0.9615
# Epoch 6/25
# 4550/4550 [==============================] - 10s 2ms/step - loss: 0.1052 - accuracy: 0.9623
# Epoch 7/25
# 4550/4550 [==============================] - 10s 2ms/step - loss: 0.1024 - accuracy: 0.9631
# Epoch 8/25
# 4550/4550 [==============================] - 9s 2ms/step - loss: 0.1002 - accuracy: 0.9638
# Epoch 9/25
# 4550/4550 [==============================] - 8s 2ms/step - loss: 0.0980 - accuracy: 0.9642
# Epoch 10/25
# 4550/4550 [==============================] - 8s 2ms/step - loss: 0.0958 - accuracy: 0.9648
# Epoch 11/25
# 4550/4550 [==============================] - 10s 2ms/step - loss: 0.0938 - accuracy: 0.9653
# Epoch 12/25
# 4550/4550 [==============================] - 10s 2ms/step - loss: 0.0921 - accuracy: 0.9660
# Epoch 13/25
# 4550/4550 [==============================] - 10s 2ms/step - loss: 0.0900 - accuracy: 0.9670
# Epoch 14/25
# 4550/4550 [==============================] - 9s 2ms/step - loss: 0.0885 - accuracy: 0.9676
# Epoch 15/25
# 4550/4550 [==============================] - 9s 2ms/step - loss: 0.0874 - accuracy: 0.9683
# Epoch 16/25
# 4550/4550 [==============================] - 9s 2ms/step - loss: 0.0865 - accuracy: 0.9690
# Epoch 17/25
# 4550/4550 [==============================] - 8s 2ms/step - loss: 0.0855 - accuracy: 0.9695
# Epoch 18/25
# 4550/4550 [==============================] - 9s 2ms/step - loss: 0.0846 - accuracy: 0.9699
# Epoch 19/25
# 4550/4550 [==============================] - 9s 2ms/step - loss: 0.0836 - accuracy: 0.9703
# Epoch 20/25
# 4550/4550 [==============================] - 9s 2ms/step - loss: 0.0823 - accuracy: 0.9707
# Epoch 21/25
# 4550/4550 [==============================] - 8s 2ms/step - loss: 0.0810 - accuracy: 0.9710
# Epoch 22/25
# 4550/4550 [==============================] - 9s 2ms/step - loss: 0.0799 - accuracy: 0.9715
# Epoch 23/25
# 4550/4550 [==============================] - 11s 2ms/step - loss: 0.0789 - accuracy: 0.9720
# Epoch 24/25
# 4550/4550 [==============================] - 14s 3ms/step - loss: 0.0777 - accuracy: 0.9723
# Epoch 25/25
# 4550/4550 [==============================] - 13s 3ms/step - loss: 0.0768 - accuracy: 0.9724

# %%
# Results - Accuracy
scores = model.evaluate(X_train, y_train) # verbose = False)
print("Training Accuracy: %.2f%%\n" % (scores[1] * 100))  # loss: 0.0478 - accuracy: 0.9840

scores = model.evaluate(X_test, y_test) # verbose = False) loss 
print("Testing Accuracy: %.2f%%\n" % (scores[1] * 100)) #   loss: 0.0485 - accuracy: 0.9834
# Out:
# 14216/14216 [==============================] - 27s 2ms/step - loss: 0.0754 - accuracy: 0.9728
# Training Accuracy: 97.28%
#
# 3554/3554 [==============================] - 6s 2ms/step - loss: 0.0756 - accuracy: 0.9727
# Testing Accuracy: 97.27%

# %%
# Evaluating the predictions of the model
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_test_pred = model.predict(X_test)
y_test_pred = y_test_pred.flatten()
y_test_pred_new = np.where(y_test_pred.round(2) > 0.5, 1, 0)
c_matrix = confusion_matrix(y_test, y_test_pred_new)
c_matrix
# Out:
# 3554/3554 [==============================] - 5s 1ms/step
# array([[55766,  1097],
#        [ 2001, 54862]], dtype=int64)

# %%
#Checking the perfomance of the model with a confussion matrix
import seaborn as sns
# Predicting the Test set results
y_pred = model.predict(X_test).flatten().round()

#Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
import seaborn as sns
sns.heatmap(cm, annot=True)

#Verify the accuracy of the model
from sklearn.metrics import accuracy_score
print('ANN accurary:',accuracy_score(y_test,y_pred))

# Classification report 
from sklearn.metrics import f1_score , precision_score , recall_score , classification_report
print('classification_report:',classification_report(y_test,y_pred))
print('f1_score:',f1_score(y_test,y_pred))
print('precision_score:',precision_score(y_test,y_pred))
print('recall_score:',recall_score(y_test,y_pred))
# Out:
# 3554/3554 [==============================] - 5s 1ms/step
# ANN: 0.9726975361834584
# classification_report:               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     56863
#            1       0.98      0.97      0.97     56863
#
#     accuracy                           0.97    113726
#    macro avg       0.97      0.97      0.97    113726
# weighted avg       0.97      0.97      0.97    113726
#
# f1_score: 0.9724897445666137
# precision_score: 0.979947860867081
# recall_score: 0.9651442941807502

# %% [markdown]
# **Discussion:** As seen above, the model loss has been reduced when using 25 epochs and acuracy remains between 97% producing better results.
#
# I had 142,158 number of transactions in my test set. Out of 68,661 were predicted to be legitimate transactions, and 3,067 were classified as being legitimate, when  there were not (type one error). It correctly predicted 68,116 transactions as being product of fraud and 2314 as being not legitimate ones, when they really are (type two error).

# %%
# Get training and test loss histories
history = model.fit(X_train, y_train, epochs=25, verbose=0, validation_data=(X_test, y_test))

# %%
#Visualizing the loss in train set 
#plt.figure(figsize=(7,5))
plt.title('Loss') 
plt.plot(history.history['loss'], label='train') 
plt.plot(history.history['val_loss'], label='test') 
plt.legend(["Training Loss", "Test Loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show();

# %% [markdown]
# **Alternatively, we can use the same approach to visualize the training and test accuracy over each epoch**

# %%
# plot accuracy during training 

plt.title('Accuracy') 
plt.plot(history.history['accuracy'], label='train') 
plt.plot(history.history['val_accuracy'], label='test') 
plt.legend(["Training Accuracy", "Test Accuracy"])
plt.xlabel("Epoch")
plt.ylabel("Accuracy Score")
plt.show()

# %% [markdown]
# ## Compare ANN with Random Forest Classifier

# %% [markdown]
# A Random Forest classifier is going to be prepared to compared the results with ANN model. Train test and test set for X and y are going to be the same.

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf = RandomForestClassifier(n_estimators = 100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)

y_pred = clf.predict(X_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred)) ##0.9795
# Out:
# Accuracy: 0.9997977595272849

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Calculate cm by calling a method named as 'confusion_matrix'
cm = confusion_matrix(y_test, y_pred)

# Call a method heatmap() to plot confusion matrix
sns.heatmap(cm, annot = True)

# print the classification_report based on y_test and y_predict
print(classification_report(y_test, y_pred))

# Classification report 
from sklearn.metrics import f1_score , precision_score , recall_score , classification_report
print('f1_score:',f1_score(y_test,y_pred))
print('precision_score:',precision_score(y_test,y_pred))
print('recall_score:',recall_score(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56863
#            1       1.00      1.00      1.00     56863
#
#     accuracy                           1.00    113726
#    macro avg       1.00      1.00      1.00    113726
# weighted avg       1.00      1.00      1.00    113726
#
# f1_score: 0.9997977968649722
# precision_score: 0.9996132480135012
# recall_score: 0.9999824138719379

# %% [markdown]
# ## Shape of data did not changed after Standarization

# %%
from sklearn.preprocessing import StandardScaler
Credit["standardized"]=StandardScaler().fit_transform(Credit[["V4"]])

# %%
from matplotlib import pyplot as plt
fig, (ax1, ax2) = plt.subplots(2,1,figsize=(7, 5))
fig.tight_layout(pad=3.0)

Credit['V4'].hist(ax=ax1, bins=100)
ax1.tick_params(labelsize=12)
ax1.set_xlabel('V4 feature before standarization', fontsize=12)
ax1.set_ylabel('V4', fontsize=12)

Credit['standardized'].hist(ax=ax2, bins=100)
ax2.tick_params(labelsize=12)
ax2.set_xlabel('V4 feature after standarization', fontsize=12)
ax2.set_ylabel('V4', fontsize=12)
# Out:
# Text(47.5, 0.5, 'V4')

# %% [markdown]
# **Discussion:** After performing ANN and RF classifier, was possible to see that ANN produced more accurate predictions while Random forest model was overfitted while tested with the same parameters. As demostrated on previous research, when using big data, traditional machine learning models do not perform well. In contrast, Deep learning model, as ANN in this case produced better results to identify the number of fraudulent transactions.

# %% [markdown]
# **References:**
#
# https://www.kaggle.com/datasets/nelgiriyewithana/credit-card-fraud-detection-dataset-2023
#
# McQuaid, D. (2023). Loss Functions – Advanced Data for Analytics Module. [Accessed 20 September, 2023].
#
# Iqbal, M. (2022). Tutorial 6 ANN.  Case Study (Artificial Neural Network lecture). Machine Learning for Data Analytics module.[Accessed 20 September, 2023].
#
# McQuaid, D. (2023).– Feature Scaling or Normalization – Data Preparation and Visualization for Data Analytics Module. [Accessed 20 September 2023].
